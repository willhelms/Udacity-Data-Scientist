# %% [markdown]
# ## Exploring Covid-19 Dataset
#
# Source : https://github.com/owid/covid-19-data/tree/master/public/data/
#
# by     : William

# %% [markdown]
# Currently, the world is occupied by the new pandemic, Covid-19. The effect of this virus is massive. Hopefully, the information regarding this virus has been provided by many sources. We can analyze how the virus statistics.
#
# In this notebook, i try to exploring dataset regarding the virus.
#
# Some questions that will be asked:
# 1. What are the countries that have high total virus cases?
# 2. What are the countries that have high new virus cases?
# 3. What are the countries that have high deaths beacuse of the virus?
# 4. What are the countries that have high new deaths beacuse of the virus?
# 5. Is the a correlation between cases and deaths?

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

df = pd.read_csv('owid-covid-data.csv')
df.sample(10)
# Out:
#       iso_code                   location        date  total_cases  new_cases  \
# 7253       JOR                     Jordan  2020-03-23           99         15
# 4095       EGY                      Egypt  2020-02-17            1          0
# 5618       GRD                    Grenada  2020-03-26            1          0
# 12964      SXM  Sint Maarten (Dutch part)  2020-04-21           68          1
# 2038       BRB                   Barbados  2020-03-24           17          0
# 8524       LTU                  Lithuania  2020-04-15         1070          0
# 10546      NZL                New Zealand  2020-01-12            0          0
# 1199       BEN                      Benin  2020-03-22            2          0
# 5045       GBR             United Kingdom  2020-04-26       148377       4913
# 5188       GGY                   Guernsey  2020-04-04          114         23
#
#        total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
df.shape
# Out:
# (14710, 16)

# %% [markdown]
# There is 14710 data and 16 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14710 entries, 0 to 14709
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  14522 non-null  object
#  1   location                  14710 non-null  object
#  2   date                      14710 non-null  object
#  3   total_cases               14710 non-null  int64
#  4   new_cases                 14710 non-null  int64
#  5   total_deaths              14710 non-null  int64
#  6   new_deaths                14710 non-null  int64
#  7   total_cases_per_million   14422 non-null  float64
#  8   new_cases_per_million     14422 non-null  float64
#  9   total_deaths_per_million  14422 non-null  float64
#  10  new_deaths_per_million    14422 non-null  float64
#  11  total_tests               3697 non-null   float64
#  12  new_tests                 3302 non-null   float64
# ...

# %% [markdown]
# There is not missing data in total cases, new cases, total death, new death columns.
#
# The dataset is clean and can be explored,

# %%
df.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.471000e+04   14710.000000   14710.000000  14710.000000
# mean   1.033838e+04     449.707682     665.024609     32.417539
# std    1.097793e+05    4261.794616    7600.146515    331.161869
# min    0.000000e+00   -1430.000000       0.000000      0.000000
# 25%    1.000000e+00       0.000000       0.000000      0.000000
# 50%    3.500000e+01       1.000000       0.000000      0.000000
# 75%    5.577500e+02      30.000000       9.000000      1.000000
# max    3.307600e+06  101716.000000  238431.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             14422.000000           14422.000000
# mean                314.044212              12.397102
# std                1083.980599              67.458408
# min                   0.000000             -38.570000
# 25%                   0.072000               0.000000
# 50%                   8.036000               0.107000
# ...

# %% [markdown]
# The descriptive statistics for the data. We can see that the total cases has higher mean and standard deviation than total death. Which i think a good thing because many people are being treated and is not death by the virus.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hopefully, There is no duplicated data

# %%
df.groupby('location').sum()['total_cases']
# Out:
# location
# Afghanistan          30204
# Albania              18653
# Algeria              78431
# Andorra              22685
# Angola                 671
#                     ...
# Western Sahara          42
# World             76167832
# Yemen                   39
# Zambia                2045
# Zimbabwe               694
# Name: total_cases, Length: 211, dtype: int64

# %%
# new_cases_by_location = df.groupby('location').sum().reset_index()
# new_cases_by_location.sort_values('new_cases', ascending=False)
# Out:
#                             location  total_cases  new_cases  total_deaths  \
# 207                            World     76167832    3307600       4903616
# 199                    United States     21795280    1103781       1050419
# 177                            Spain      5923522     215216        601854
# 98                             Italy      6348813     207428        789120
# 198                   United Kingdom      3351215     177454        495503
# ..                               ...          ...        ...           ...
# 206                   Western Sahara           42          6             0
# 24   Bonaire Sint Eustatius and Saba          125          6             0
# 5                           Anguilla          104          3             0
# 43                           Comoros            1          1             0
# 87                         Hong Kong            0          0             0
#
#      new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
# total_cases = df.groupby('location').sum().reset_index()
# total_cases.sort_values('total_cases', ascending=False)
# Out:
#            location  total_cases  new_cases  total_deaths  new_deaths  \
# 207           World     76167832    3307600       4903616      238431
# 199   United States     21795280    1103781       1050419       65068
# 41            China      6817233      83959        271606        4637
# 98            Italy      6348813     207428        789120       28236
# 177           Spain      5923522     215216        601854       24824
# ..              ...          ...        ...           ...         ...
# 206  Western Sahara           42          6             0           0
# 208           Yemen           39          7             4           2
# 186      Tajikistan           30         15             0           0
# 43          Comoros            1          1             0           0
# 87        Hong Kong            0          0             0           0
#
#      total_cases_per_million  new_cases_per_million  total_deaths_per_million  \
# ...

# %%
total_cases = df.groupby('location').sum().reset_index()
total_cases.sort_values('total_cases', ascending=False)
plt.figure(figsize=(14.70, 8.27))
x = total_cases.sort_values('total_cases', ascending=False).total_cases[1:11]
y = total_cases.sort_values('total_cases', ascending=False).location[1:11]
plt.bar(y, x)

plt.title('Countries with Highest New Cases', fontsize=20)
plt.xticks(rotation=23)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of New Cases  per Million', fontsize=12)
plt.ticklabel_format(style='plain', axis='y')

# %%
plt.plot(np.arange(0,100,10) + 1000, np.arange(0,100,10))
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
plt.draw()

# %%
plt.figure(figsize=(14.70, 8.27))
x = new_cases_by_location.sort_values('new_cases', ascending=False).new_cases[1:11]
y = new_cases_by_location.sort_values('new_cases', ascending=False).location[1:11]
plt.bar(y, x)
plt.title('Countries with Highest New Cases ', fontsize=20)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of New Cases', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of New Cases')

# %%
new_cases_per_million = df.groupby('location').sum().reset_index()
new_cases_per_million.sort_values('new_cases_per_million', ascending=False)
plt.figure(figsize=(14.70, 8.27))
x = new_cases_per_million.sort_values('new_cases_per_million', ascending=False).new_cases_per_million[0:19]
y = new_cases_per_million.sort_values('new_cases_per_million', ascending=False).location[0:19]
plt.bar(y, x)
plt.title('Countries with Highest New Cases', fontsize=20)
plt.xticks(rotation=23)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of New Cases  per Million', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of New Cases  per Million')

# %%
death_by_location = df.groupby('location').sum().reset_index()
death_by_location.sort_values('total_deaths', ascending=False)
# Out:
#                             location  total_cases  new_cases  total_deaths  \
# 207                            World     76167832    3307600       4903616
# 199                    United States     21795280    1103781       1050419
# 98                             Italy      6348813     207428        789120
# 177                            Spain      5923522     215216        601854
# 68                            France      3562358     130185        531528
# ..                               ...          ...        ...           ...
# 135                            Nepal          926         59             0
# 24   Bonaire Sint Eustatius and Saba          125          6             0
# 176                      South Sudan          232         45             0
# 22                            Bhutan          219          7             0
# 87                         Hong Kong            0          0             0
#
#      new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
plt.figure(figsize=(14.70, 8.27))
x = death_by_location.sort_values('total_deaths', ascending=False).total_deaths[1:11]
y = death_by_location.sort_values('total_deaths', ascending=False).location[1:11]
plt.bar(y, x)
plt.title('Countries with Highest Death ', fontsize=20)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of total deaths', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of total deaths')

# %%
total_deaths = df.groupby('location').sum().reset_index()
total_deaths.sort_values('total_deaths_per_million', ascending=False)
plt.figure(figsize=(14.70, 8.27))
x = total_deaths.sort_values('total_deaths_per_million', ascending=False).total_deaths_per_million[0:19]
y = total_deaths.sort_values('total_deaths_per_million', ascending=False).location[0:19]
plt.bar(y, x)
plt.title('Countries with Highest New Cases', fontsize=20)
plt.xticks(rotation=23)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of New Cases  per Million', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of New Cases  per Million')

# %%
plt.scatter(x=df.total_cases, y=df.total_deaths, alpha=0.4)
